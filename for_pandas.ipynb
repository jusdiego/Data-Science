# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('netflix.csv')
df
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# Obtendo dados de amostra

df.sample(5)
# Out:
#      show_id     type                      title          director  \
# 1494   s2343    Movie  Game Over (Hindi Version)  Ashwin Saravanan
# 4259   s4832  TV Show         Person of Interest               NaN
# 4538   s5083  TV Show                       Rake               NaN
# 395    s1354    Movie  Chris D'Elia: Man on Fire       Bill D'Elia
# 6544    s689    Movie                Bad Boys II       Michael Bay
#
#                                                    cast        country  \
# 1494  Taapsee Pannu, Vinodhini, Parvathi T, Ramya Su...            NaN
# 4259  Jim Caviezel, Michael Emerson, Taraji P. Henso...  United States
# 4538  Richard Roxburgh, Matt Day, Adrienne Pickering...      Australia
# 395                                        Chris D'Elia  United States
# 6544  Will Smith, Martin Lawrence, Jordi Mollà, Gabr...  United States
#
#                date_added  release_year rating  duration  \
# 1494            21-Aug-19          2019  TV-MA        98
# ...

# %%
# Dimensões do DataFrame

df.shape
# Out:
# (7787, 12)

# %%
# Nomes das colunas

df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'description'],
#       dtype='object')

# %%
# Informações basicas 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %%
# Tipos da colunas

df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration         int64
# genres          object
# description     object
# dtype: object

# %%
# Alterando o tipo de dados de date_added

df["date_added"] = pd.to_datetime(df["date_added"])

# %%
# Verificando dtype se foi alterado ou não

df["date_added"].dtype
# Out:
# dtype('<M8[ns]')

# %%
# verificando valores nulos

df.isnull().sum().sort_values(ascending=False)
# Out:
# director        2389
# cast             718
# country          507
# date_added        10
# rating             7
# show_id            0
# type               0
# title              0
# release_year       0
# duration           0
# genres             0
# description        0
# dtype: int64

# %%
# Checando porcentagem de valores nulos

for i in df.columns:
    if df[i].isnull().any():
        print(i,"---------",df[i].isnull().sum()*100/df.shape[0],"%")
# Out:
# director --------- 30.679337357133683 %
# cast --------- 9.220495697958135 %
# country --------- 6.510851419031719 %
# date_added --------- 0.1284191601386927 %
# rating --------- 0.08989341209708489 %

# %%
df[df["rating"].isnull()]
# Out:
#      show_id     type                                              title  \
# 1513   s2360  TV Show                  Gargantia on the Verdurous Planet
# 2958   s3661  TV Show                                       Little Lunch
# 3042   s3737    Movie                                    Louis C.K. 2017
# 3043   s3738    Movie                              Louis C.K.: Hilarious
# 3044   s3739    Movie               Louis C.K.: Live at the Comedy Store
# 3695   s4324    Movie                               My Honor Was Loyalty
# 6444     s68    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
#
#              director                                               cast  \
# 1513              NaN  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 2958              NaN  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 3042       Louis C.K.                                         Louis C.K.
# 3043       Louis C.K.                                         Louis C.K.
# ...

# %%
df["rating"].unique()
# Out:
# array(['TV-MA', 'TV-PG', 'R', 'TV-G', 'PG-13', 'TV-14', 'TV-Y', 'PG',
#        'TV-Y7', 'NR', 'G', 'TV-Y7-FV', nan, 'UR', 'NC-17'], dtype=object)

# %%
# Preenchendo programa de TV com tv-14, pois são anime e programa infantil

l = [1513, 2958]
for i in l:
    df["rating"].iloc[i] = "TV-14"
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_816\663101330.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rating"].iloc[i] = "TV-14"
# C:\Users\diego\AppData\Local\Temp\ipykernel_816\663101330.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rating"].iloc[i] = "TV-14"

# %%
l = [3042, 3043, 3044, 3695, 6444]
for i in l:
    df["rating"].iloc[i] = "TV-MA"
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_816\2399001216.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rating"].iloc[i] = "TV-MA"
# C:\Users\diego\AppData\Local\Temp\ipykernel_816\2399001216.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rating"].iloc[i] = "TV-MA"
# C:\Users\diego\AppData\Local\Temp\ipykernel_816\2399001216.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
